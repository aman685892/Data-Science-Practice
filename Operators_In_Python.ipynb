# %% [markdown]
# <a href="https://colab.research.google.com/github/aman685892/Data-Science-Practice/blob/main/Operators_In_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=10
b=5
add_result=a+b
sub_result=a-b
mul_result=a*b
div_result=a/b
floor_div_result=a//b
modulo_result=a%b
exp_result=a**b
print(add_result)
print(sub_result)
print(mul_result)
print(div_result)
print(floor_div_result)
print(modulo_result)
print(exp_result)
# Out:
# 15
# 5
# 50
# 2.0
# 2
# 0
# 100000

# %%
21/5
# Out:
# 4.2

# %%
a=10
b=10
a==b
# Out:
# True

# %%
name="Aman"
Name="aman"
print(name==Name)
# Out:
# False

# %%
## not equal to !=
str1="Rahul"
str2="Raj"
str1!=str2
# Out:
# True

# %%
num1=67
num2=78
num1>num2
# Out:
# False

# %%
num1<num2
# Out:
# True

# %%
number1=567
number2=567
number1>=number2
# Out:
# True

# %%
number1<=number2
# Out:
# True

# %%
## Logical opeartors
## And,Or,Not
x=True
y=True
x and y
# Out:
# True

# %%
x=False
y=True
print(x and y)
# Out:
# False

# %%
x or y
# Out:
# True

# %%
a=False
b=False
a or b
# Out:
# False
