# %% [markdown]
# <a href="https://colab.research.google.com/github/aman685892/Data-Science-Practice/blob/main/Basics_Data_Types_In_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## integer data type
age=21
print(age,type(age))
# Out:
# 21 <class 'int'>

# %%
## floating type
height=5.6
print(height,type(height))
# Out:
# 5.6 <class 'float'>

# %%
## string
name="aman"
print(name,type(name))
# Out:
# aman <class 'str'>

# %%
## boolean
is_student=True
print(is_student)
print(type(is_student))
# Out:
# True
# <class 'bool'>

# %%
result="Hello"+str(6)
print(result)
# Out:
# Hello6
