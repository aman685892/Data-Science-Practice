# %% [markdown]
# <a href="https://colab.research.google.com/github/aman685892/Data-Science-Practice/blob/main/Variables_In_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## declaring and assigning variables
age=23
name="Aman"
height=5.1
is_student=False
print(age)
print(name)
print(height)
print(is_student)
# Out:
# 23
# Aman
# 5.1
# False

# %%
## case sensitive variable
name="aman"
Name="Raj"
print(name)
print(Name)
# Out:
# aman
# Raj

# %%
first_name="aman"
last_name="kumar"
print(first_name)
print(last_name)
# Out:
# aman
# kumar

# %%
name="Rahul"
age=23
height=6.7

# %%
age=21
print(type(age))
# Out:
# <class 'int'>

# %%
print(type(str(age)))
# Out:
# <class 'str'>

# %%
name="aman kumar"
int(name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_7014/1612065490.py in <cell line: 0>()
#       1 name="aman kumar"
# ----> 2 int(name)
#
# ValueError: invalid literal for int() with base 10: 'aman kumar'

# %%
height=5.1
type(height)
# Out:
# float

# %%
int(height)
# Out:
# 5

# %%
float(height)
# Out:
# 5.1

# %%
x=int(height)
print(x)
# Out:
# 5

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
## Dynamic typing
## python allows the type of varibale to change as the program executes
age=21
print(age,type(age))
age="Aman"
print(age,type(age))
age=6.7
print(age,type(age))
# Out:
# 21 <class 'int'>
# Aman <class 'str'>
# 6.7 <class 'float'>

# %%
## To take input from the user
Age=int(input("What is the age of your"))
print(Age, type(Age))
# Out:
# What is the age of your45
# 45 <class 'int'>

# %%
## simple calculator
num1=float(input("Enter number1"))
num2=float(input("Enter number2"))
sum=num1+num2
difference=num1-num2
product=num1*num2
division=num1/num2
print(sum,type(sum))
print(difference,type(difference))
print(product,type(product))
print(division,type(division))
# Out:
# Enter number134.8
# Enter number278.9
# 113.7 <class 'float'>
# -44.10000000000001 <class 'float'>
# 2745.72 <class 'float'>
# 0.4410646387832699 <class 'float'>
