# %% [markdown]
# <a href="https://colab.research.google.com/github/aman685892/Data-Science-Practice/blob/main/Python_Basics_Syntax_And_Semantics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Case Sensitivity
name="aman"
Name="Raj"
print(name)
print(Name)
# Out:
# aman
# Raj

# %%
## Line continuation
total=1+2+3+5+7+\
8+9

print(total)
# Out:
# 35

# %%
x=6;y=7;z=x+y ## Multiple statements on a single line
print(z)
# Out:
# 13

# %%
## Type inferencing
variable=10
print(type(variable))
variable="aman"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
## Code example of indentation
if True:
  print("Hello")
  if False:
    print("World")
  print("ok")
print("done")
# Out:
# Hello
# ok
# done
